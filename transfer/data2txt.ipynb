# %%
import pandas as pd
import os
from astropy.io import fits
ain = pd.read_csv('/data/renhaoye/MorCG_DECaLS/dataset/overlap_mw.txt',sep=' ')
print(ain.shape)
ain.head()
# Out:
# (3618, 69)
#                                                  loc  \
# 0  /data/renhaoye/MorCG/dataset/in_decals/agmtn/1...
# 1  /data/renhaoye/MorCG/dataset/in_decals/agmtn/3...
# 2  /data/renhaoye/MorCG/dataset/in_decals/agmtn/3...
# 3  /data/renhaoye/MorCG/dataset/in_decals/agmtn/4...
# 4  /data/renhaoye/MorCG/dataset/in_decals/agmtn/1...
#
#    smooth_or_featured_smooth  smooth_or_featured_featured_or_disk  \
# 0                   0.764829                             0.125099
# 1                   0.457121                             0.485342
# 2                   0.512107                             0.439786
# 3                   0.828821                             0.112583
# 4                   0.837709                             0.067217
#
#    smooth_or_featured_artifact  disk_edge_on_yes  disk_edge_on_no  \
# 0                     0.110072          0.155213         0.844787
# 1                     0.057537          0.027560         0.972440
# ...

# %%
# dir = '/data/GZ_Decals/MGS_out_DECaLS/'
dir1 = '/data/renhaoye/MorCG/dataset/out_decals/scaled/'
train = open('train_tal1.txt', 'w')

for b in range(len(ain['loc'])):
    ss = ain['loc'][b]
    name = ain['loc'][b] + ' ' + dir1 + ain['loc'][b][45:] + '\n'
    train.write(name)

train.close()
