# %%
import pandas as pd
ain = pd.read_csv('/data/renhaoye/decals_2022/in_decals_overlap_fraction.csv')
ain1 = pd.read_csv('/data/renhaoye/decals_2022/in_decals2match.csv')
ain2 = pd.read_csv('/data/renhaoye/decals_2022/out_decals2match.csv')
# print(ain.head())
print(ain1.head())
print(ain2.head())
print(ain.shape)
print(ain1.shape)
print(ain2.shape)
ain.head()
# Out:
#    Unnamed: 0          ra        dec
# 0           0  234.869207  21.759190
# 1           1  195.388715   5.035083
# 2           2  200.468517  -0.949762
# 3           3  203.926529   6.158162
# 4           4  170.696841  -0.525081
#    Unnamed: 0          ra        dec
# 0           0  174.591947  24.207861
# 1           1  190.779922  11.060281
# 2           2  342.351266   0.176709
# 3           3  200.983026  38.007239
# 4           4  254.384417  39.470698
# (3463, 92)
# (313382, 3)
# (457118, 3)
#    Unnamed: 0          ra        dec              iauname  petro_theta  \
# 0           0  175.890586  21.669819  J114333.71+214011.3    11.761320
# 1           1  176.147779   6.430212  J114435.46+062548.7    13.916864
# 2           2  216.734203  -2.556704  J142656.20-023324.1    21.376790
# 3           3  249.263232  26.699682  J163703.40+264157.0     6.613727
# 4           4  229.357805  12.945866  J151725.87+125645.1    13.142800
#
# ...

# %%
ain.head()
# Out:
#    Unnamed: 0          ra        dec              iauname  petro_theta  \
# 0           0  175.890586  21.669819  J114333.71+214011.3    11.761320
# 1           1  176.147779   6.430212  J114435.46+062548.7    13.916864
# 2           2  216.734203  -2.556704  J142656.20-023324.1    21.376790
# 3           3  249.263232  26.699682  J163703.40+264157.0     6.613727
# 4           4  229.357805  12.945866  J151725.87+125645.1    13.142800
#
#    petro_th50  petro_th90  elpetro_absmag_r  sersic_nmgy_r  redshift  ...  \
# 0    5.081815   12.596584        -21.246426      203.72523  0.099172  ...
# 1    6.035047   18.316315        -21.767908      458.95126  0.103689  ...
# 2   10.158915   31.909264        -22.527197     1887.89530  0.082288  ...
# 3    3.444424   10.334829        -20.715216     1071.42580  0.058080  ...
# 4    5.932321   15.874659        -21.615564     1499.35360  0.061528  ...
#
#    bar_proportion_volunteers_asked bulge-size_proportion_volunteers_asked  \
# ...

# %%
len(ain)
# Out:
# 3463

# %%
import os
mu = os.listdir('/data/GZ_Decals/merge')
print(len(mu))
dd = []
for i in mu:
    tep = i.split('_')[:2]
    try:
        tep = [eval(j) for j in tep]
        tep.append('/data/GZ_Decals/merge/'+i)
    except:
        continue
    dd.append(tep)
mu = os.listdir('/data/GZ_Decals/nomerge')
for i in mu:
    tep = i.split('_')[:2]
    try:
        tep = [eval(j) for j in tep]
        tep.append('/data/GZ_Decals/nomerge/'+i)
    except:
        continue
    dd.append(tep)
print(len(mu))
# Out:
# 3209
# 310580

# %%
print(len(dd))
data1 = pd.DataFrame(dd)
data1.head()
# Out:
# 313787
#             0          1                                                  2
# 0   33.906601   1.441015  /data/GZ_Decals/merge/33.90660141789699_1.4410...
# 1  192.422777   7.229068  /data/GZ_Decals/merge/192.42277675686236_7.229...
# 2  318.568319  10.593742  /data/GZ_Decals/merge/318.56831910552484_10.59...
# 3  234.447449  17.048572  /data/GZ_Decals/merge/234.44744913052855_17.04...
# 4  246.700931  14.439419  /data/GZ_Decals/merge/246.7009312215524_14.439...

# %%
from tqdm import tqdm
import numpy as np
dd = []
for j in tqdm(range(len(ain))):
    da = data1[(data1[data1.columns[0]]==ain.iloc[j,1]) & (data1[data1.columns[1]]==ain.iloc[j,2])]
    if len(da) ==  1:
        da1 = da
    else:
        da = data1[(abs(data1[data1.columns[0]]-ain.iloc[j,1])<1e-4) & (abs(data1[data1.columns[1]]-ain.iloc[j,2])<1e-4)]
        if len(da) !=  0:
            da1 = da
        # da = data1[(abs(data1[data1.columns[0]]-ain.iloc[j,1])<1e-4) & (abs(data1[data1.columns[1]]-ain.iloc[j,2])<1e-6)]
        else:
            continue
    re = da1.index.item()
    if type(re)!=int:
        re = re[0]
    re1 = np.hstack((data1.iloc[re,2],re,j))
    dd.append(re1)
dd = np.array(dd)
# Out:
# 100%|██████████| 3463/3463 [00:16<00:00, 209.79it/s]

# %%
print(dd[:10])
print(len(dd))
# print(j)
# print(len(da1))
# print(da)
# print(da1)
# Out:
# [['/data/GZ_Decals/nomerge/175.8905862789053_21.66981935317594_0.fits'
#   '205503' '0']
#  ['/data/GZ_Decals/nomerge/176.14777944132385_6.43021218747715_0.fits'
#   '139974' '1']
#  ['/data/GZ_Decals/nomerge/216.73420321996912_-2.5567049269072277_0.fits'
#   '266784' '2']
#  ['/data/GZ_Decals/merge/249.2632324703534_26.69968242446739_0.fits'
#   '1569' '3']
#  ['/data/GZ_Decals/nomerge/229.35780548542343_12.945866234484898_0.fits'
#   '310266' '4']
#  ['/data/GZ_Decals/nomerge/133.7835302320826_23.36520378191616_0.fits'
#   '34632' '5']
#  ['/data/GZ_Decals/merge/248.28280495363862_26.93795912767684_0.fits'
#   '2435' '6']
#  ['/data/GZ_Decals/nomerge/139.95418651016448_4.484699228903079_0.fits'
#   '97624' '7']
#  ['/data/GZ_Decals/nomerge/173.48752178909703_21.09361120700463_0.fits'
#   '203549' '8']
#  ['/data/GZ_Decals/nomerge/174.28095256613472_17.9886942041124_0.fits'
#   '207312' '9']]
# 3463

# %%
adre = pd.DataFrame(dd)
adre.columns = ['address','rank1','rank2']
adre.head()
# Out:
#                                              address   rank1 rank2
# 0  /data/GZ_Decals/nomerge/175.8905862789053_21.6...  205503     0
# 1  /data/GZ_Decals/nomerge/176.14777944132385_6.4...  139974     1
# 2  /data/GZ_Decals/nomerge/216.73420321996912_-2....  266784     2
# 3  /data/GZ_Decals/merge/249.2632324703534_26.699...    1569     3
# 4  /data/GZ_Decals/nomerge/229.35780548542343_12....  310266     4

# %%
dat = pd.concat([ain,adre],axis=1)
dat.head()
# Out:
#    Unnamed: 0          ra        dec              iauname  petro_theta  \
# 0           0  175.890586  21.669819  J114333.71+214011.3    11.761320
# 1           1  176.147779   6.430212  J114435.46+062548.7    13.916864
# 2           2  216.734203  -2.556704  J142656.20-023324.1    21.376790
# 3           3  249.263232  26.699682  J163703.40+264157.0     6.613727
# 4           4  229.357805  12.945866  J151725.87+125645.1    13.142800
#
#    petro_th50  petro_th90  elpetro_absmag_r  sersic_nmgy_r  redshift  ...  \
# 0    5.081815   12.596584        -21.246426      203.72523  0.099172  ...
# 1    6.035047   18.316315        -21.767908      458.95126  0.103689  ...
# 2   10.158915   31.909264        -22.527197     1887.89530  0.082288  ...
# 3    3.444424   10.334829        -20.715216     1071.42580  0.058080  ...
# 4    5.932321   15.874659        -21.615564     1499.35360  0.061528  ...
#
#    edge-on-bulge_proportion_volunteers_asked  \
# ...

# %%
dat.to_csv('result1.csv')

# %%
dat.columns
# for b in adre['address']:
    # print(b)
# Out:
# Index(['Unnamed: 0', 'ra', 'dec', 'iauname', 'petro_theta', 'petro_th50',
#        'petro_th90', 'elpetro_absmag_r', 'sersic_nmgy_r', 'redshift', 'mag_r',
#        'smooth-or-featured_smooth_concentration',
#        'smooth-or-featured_featured-or-disk_concentration',
#        'smooth-or-featured_artifact_concentration',
#        'disk-edge-on_yes_concentration', 'disk-edge-on_no_concentration',
#        'has-spiral-arms_yes_concentration', 'has-spiral-arms_no_concentration',
#        'bar_strong_concentration', 'bar_weak_concentration',
#        'bar_no_concentration', 'bulge-size_dominant_concentration',
#        'bulge-size_large_concentration', 'bulge-size_moderate_concentration',
#        'bulge-size_small_concentration', 'bulge-size_none_concentration',
#        'how-rounded_round_concentration',
#        'how-rounded_in-between_concentration',
#        'how-rounded_cigar-shaped_concentration',
#        'edge-on-bulge_boxy_concentration', 'edge-on-bulge_none_concentration',
# ...

# %%
import os
from astropy.io import fits

train = open('train_tf1.txt', 'w')

for b in adre['address']:
    ss = b
    try:
        name = ss + '\n'
        hdu = fits.open(ss)
        img = hdu[0].data
        if len(img)==3 and len(img[0])==256:
            hdu.close()
            train.write(name)
    except:
        continue

train.close()
